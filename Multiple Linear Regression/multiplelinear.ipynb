# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
california=fetch_california_housing()

# %%
california
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]], shape=(20640, 8)),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
# ...

# %%
california.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_bunch.py:57, in Bunch.__getattr__(self, key)
#      56 try:
# ---> 57     return self[key]
#      58 except KeyError:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_bunch.py:42, in Bunch.__getitem__(self, key)
#      38     warnings.warn(
#      39         self._deprecated_key_to_warnings[key],
#      40         FutureWarning,
#      41     )
# ---> 42 return super().__getitem__(key)
#
# KeyError: 'head'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 california.head()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_bunch.py:59, in Bunch.__getattr__(self, key)
# ...

# %% [markdown]
# Exploring the Dataset

# %%
california.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
print(california.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
print(california.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
print(california.data)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
california['data']
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]], shape=(20640, 8))

# %%
california['target']
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,))

# %%
california['feature_names']
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
california['frame']

# %%
california = fetch_california_housing(as_frame=True)
california.frame.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
california['target_names']
# Out:
# ['MedHouseVal']

# %%
print(california['DESCR'])
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
california.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_bunch.py:57, in Bunch.__getattr__(self, key)
#      56 try:
# ---> 57     return self[key]
#      58 except KeyError:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_bunch.py:42, in Bunch.__getitem__(self, key)
#      38     warnings.warn(
#      39         self._deprecated_key_to_warnings[key],
#      40         FutureWarning,
#      41     )
# ---> 42 return super().__getitem__(key)
#
# KeyError: 'info'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 california.info()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_bunch.py:59, in Bunch.__getattr__(self, key)
# ...

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

# Load dataset
california = fetch_california_housing()

# Convert to DataFrame
df = pd.DataFrame(california.data, columns=california.feature_names)
df['Target'] = california.target

# Now you can use .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Target      20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
dataset['Price']=california.target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 dataset['Price']=california.target
#
# NameError: name 'dataset' is not defined

# %% [markdown]
#  Exploratory Data Analysis (EDA) on California Housing Dataset

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

# Load data with as_frame=True to get DataFrame directly
california = fetch_california_housing(as_frame=True)
df = california.frame

# Preview the data
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
# Dataset shape
print("Dataset shape:", df.shape)

# Data types and missing values
df.info()

# Statistical summary
df.describe()
# Out:
# Dataset shape: (20640, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# ...

# %%
# Check for missing/null values
df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for all features
df.hist(figsize=(15, 10), bins=30)
plt.tight_layout()
plt.show()

# %%
df.hist(figsize=(15,10), bins=30)
plt.show()  # without tight_layout()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# Might be slow due to dataset size; you can sample
sns.pairplot(df.sample(1000), diag_kind='kde')
plt.show()

# %%
# Scatter plot for some features vs target
features = ['MedInc', 'HouseAge', 'AveRooms', 'AveOccup']

for feature in features:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(x=df[feature], y=df['MedHouseVal'])
    plt.title(f'{feature} vs Median House Value')
    plt.xlabel(feature)
    plt.ylabel('Median House Value')
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))  # Resize the plot
sns.scatterplot(data=df, x='MedInc', y='MedHouseVal', edgecolor='white')

plt.title('MedInc vs Median House Value')
plt.xlabel('MedInc')
plt.ylabel('Median House Value')
plt.tight_layout()
plt.show()

# %%
X = df.iloc[:, :-1]  # Independent variables
y = df.iloc[:, -1]   # Dependent variable (target)

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=10)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((13828, 8), (13828,), (6812, 8), (6812,))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)  # Fit and transform training data
X_test = scaler.transform(X_test)        # Only transform test data

X_train  # Now scaled
X_test   # Now scaled
# Out:
# array([[ 0.75154854, -1.31428337, -0.39376169, ...,  0.12606697,
#         -0.68820027,  0.19491761],
#        [ 0.05935857, -0.12595418, -0.33070668, ..., -0.12021013,
#          0.89459042, -1.36503888],
#        [ 0.34405687, -1.31428337, -0.41007104, ..., -0.15581759,
#         -0.91698123,  0.89764561],
#        ...,
#        [ 0.36483158,  0.27015554,  0.04216837, ..., -0.08014641,
#         -0.46875731, -0.43803598],
#        [-0.90412152, -0.91817364,  0.66736933, ..., -0.10263685,
#          2.51006411, -1.96808915],
#        [-0.43377577,  1.22081889, -0.44835491, ...,  0.2807072 ,
#         -0.74422826,  0.69330627]], shape=(6812, 8))

# %%
X_train
# Out:
# array([[-0.72986836,  1.22081889, -0.70305988, ...,  0.05861244,
#          0.96929441, -1.43979718],
#        [-0.61046678, -0.28439808,  0.07828001, ...,  0.13015917,
#         -0.75823526,  1.08204942],
#        [ 0.00784578, -0.60128586, -0.2447376 , ..., -0.09793279,
#          0.94594941, -1.2454256 ],
#        ...,
#        [ 0.88684913, -1.78961504, -0.21300658, ...,  0.09549475,
#          0.78720344, -1.10587678],
#        [-0.87672223,  0.50782138, -1.10043274, ...,  0.18513096,
#         -0.77224225,  0.66838683],
#        [-0.62742573, -0.99739558, -0.60483749, ..., -0.08418874,
#          0.77786545, -1.15073176]], shape=(13828, 8))

# %%
X_test
# Out:
# array([[ 0.75154854, -1.31428337, -0.39376169, ...,  0.12606697,
#         -0.68820027,  0.19491761],
#        [ 0.05935857, -0.12595418, -0.33070668, ..., -0.12021013,
#          0.89459042, -1.36503888],
#        [ 0.34405687, -1.31428337, -0.41007104, ..., -0.15581759,
#         -0.91698123,  0.89764561],
#        ...,
#        [ 0.36483158,  0.27015554,  0.04216837, ..., -0.08014641,
#         -0.46875731, -0.43803598],
#        [-0.90412152, -0.91817364,  0.66736933, ..., -0.10263685,
#          2.51006411, -1.96808915],
#        [-0.43377577,  1.22081889, -0.44835491, ...,  0.2807072 ,
#         -0.74422826,  0.69330627]], shape=(6812, 8))

# %% [markdown]
# MODEL TRANING

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression()
regression
# Out:
# LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([ 0.82872299,  0.1231163 , -0.27068752,  0.32859106,  0.00213572,
#        -0.02810091, -0.93017985, -0.89505497])

# %%
regression.intercept_
# Out:
# np.float64(2.0634768086491158)

# %%
y_pred = regression.predict(X_test)

# %%
y_pred
# Out:
# array([3.00397485, 2.58011486, 2.3489077 , ..., 3.09003708, 0.79152007,
#        2.04477012], shape=(6812,))

# %%
y_test
# Out:
# 20303    1.674
# 16966    3.541
# 10623    1.602
# 6146     1.408
# 2208     1.078
#          ...
# 13490    1.123
# 9340     3.020
# 17439    1.724
# 2602     0.838
# 7180     1.417
# Name: MedHouseVal, Length: 6812, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.552233239936362

# %%
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 0.5371056943007961

# %%
rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 0.743123973463622

# %%
r2 = r2_score(y_test, y_pred)
print("R-squared (R²):", r2)
# Out:
# R-squared (R²): 0.5935958526436639

# %%
n = X_test.shape[0]  # number of samples
p = X_test.shape[1]  # number of predictors
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)
print("Adjusted R-squared:", adjusted_r2)
# Out:
# Adjusted R-squared: 0.5931179409607519

# %%
#Scatter Plot: Actual vs Predicted
plt.figure(figsize=(6, 4))
plt.scatter(y_test, y_pred, color="blue", alpha=0.6)
plt.xlabel("Actual Test Values")
plt.ylabel("Predicted Test Values")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()

# %%
 #Residuals
residuals = y_test - y_pred

# %%
#  KDE Plot: Distribution of residuals
sns.displot(residuals, kind="kde", height=4, aspect=1.5)
plt.title("Distribution of Residuals (KDE)")
plt.xlabel("Residuals")
plt.grid(True)
plt.show()

# %%
#  Residuals vs Predicted
plt.figure(figsize=(6, 4))
plt.scatter(y_pred, residuals, color="red", alpha=0.6)
plt.axhline(y=0, color='black', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residuals vs Predicted Values")
plt.grid(True)
plt.show()

# %%
regression
# Out:
# LinearRegression()

# %%
import pickle
pickle.dump(regression,open('regressor.pkl','wb'))

# %%
model=pickle.load(open('regressor.pkl','rb'))

# %%
model.predict(X_test)
# Out:
# array([3.00397485, 2.58011486, 2.3489077 , ..., 3.09003708, 0.79152007,
#        2.04477012], shape=(6812,))
